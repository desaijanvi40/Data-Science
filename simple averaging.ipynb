# %%
# ==========================================
# SIMPLE AVERAGING (REGRESSION)
# ==========================================

pred_model1 = 50000
pred_model2 = 52000
pred_model3 = 51000

average_prediction = (
    pred_model1 +
    pred_model2 +
    pred_model3
) / 3

print("Average Prediction =", average_prediction)
# Out:
# Average Prediction = 51000.0
