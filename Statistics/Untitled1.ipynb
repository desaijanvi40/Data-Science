# %%
# population and sample

import pandas as pd
import numpy as np

np.random.seed(42)
population_marks=np.random.normal(loc=70,scale=10,size=1000)

df_population=pd.DataFrame(population_marks,columns=["marks"])


# head 5 rows
#tail
print(df_population.head())

# mean and variance
population_mean=df_population["marks"].mean()
population_var=df_population["marks"].var()

print(population_mean,population_var)
# Out:
#        marks
# 0  74.967142
# 1  68.617357
# 2  76.476885
# 3  85.230299
# 4  67.658466
# 70.19332055822326 95.88638535851024

# %%
#take sample of 100 students
sample_df=df_population.sample(n=100,random_state=1)

sample_mean=sample_df["marks"].mean()
sample_var=sample_df["marks"].var()

print(sample_mean,sample_var)
# Out:
# 69.98594456534424 101.79835717010698
