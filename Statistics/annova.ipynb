# %%
# Objective:

# Compare means across multiple groups.

# Scenario:

# Average marks of students in 3 different departments.

from scipy import stats

# Marks for three departments
dept1 = [65,70,72,68,75]
dept2 = [80,85,78,82,84]
dept3 = [60,62,58,65,63]

# Perform One-Way ANOVA
f_stat, p_value = stats.f_oneway(dept1, dept2, dept3)

print("F Statistic:", f_stat)
print("P Value:", p_value)

if p_value < 0.05:
    print("Reject Null Hypothesis: At least one group mean differs")
else:
    print("Fail to Reject Null Hypothesis: No significant difference")


# Determines whether the differences in group means are statistically significant.
# Out:
# F Statistic: 51.486666666666565
# P Value: 1.2927208099078801e-06
# Reject Null Hypothesis: At least one group mean differs
